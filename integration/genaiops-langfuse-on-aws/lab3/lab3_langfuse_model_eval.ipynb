# %% [markdown]
# # Evaluate Langfuse Traces using an external evaluation pipeline
#
# #### An external evaluation pipeline is useful when you need:
# - More control over when traces get evaluated. You could schedule the pipeline to run at specific times or responding to event-based triggers like Webhooks.
# - Greater flexibility with your custom evaluations, when your needs go beyond what’s possible with the Langfuse UI
# - Version control for your custom evaluations
# - The ability to evaluate data using existing evaluation frameworks and pre-defined metrics
#
# In this notebook, we will learn to implement a external evaluation pipeline by doing the following:
# 1. Create a synthetic dataset to test your models.
# 2. Use the Langfuse client to gather and filter traces of previous model runs
# 3. Evaluate these traces offline and incrementally
# 4. Add scores to existing Langfuse traces

# %%
# %pip install datasets ragas llama_index python-dotenv langchain-aws boto3 pandas --upgrade
# %pip install langfuse==2.54.1

# %%
# import all the necessary packages
from typing import Any, Dict, List, Optional, Tuple

import boto3
from botocore.exceptions import ClientError
from langfuse import Langfuse
from langfuse.decorators import langfuse_context, observe
from langfuse.model import PromptClient

# %%
# Define the environment variables
import os
os.environ["LANGFUSE_SECRET_KEY"] = "" # Your Langfuse project secret key
os.environ["LANGFUSE_PUBLIC_KEY"] = "" # Your Langfuse project public key
os.environ["LANGFUSE_HOST"] = "" # Langfuse domain

# %%
import json

from typing import List, Dict, Optional, Any

from langfuse import Langfuse
from langfuse.client import PromptClient
from langfuse.decorators import observe, langfuse_context
from botocore.exceptions import ClientError

# External Dependencies:
import boto3  # General Python SDK for AWS (including Bedrock)
import pandas as pd  # For working with tabular data
from tqdm.notebook import tqdm  # Progress bars

botosess = boto3.Session(region_name="us-east-1")
region = botosess.region_name
account_id = boto3.client('sts').get_caller_identity()['Account']

# langfuse client
langfuse = Langfuse()
langfuse.auth_check()
# Out:
# True

# %%
# used to access Bedrock configuration
bedrock = boto3.client(
    service_name="bedrock",
    region_name="us-east-1"
)
 
# used to invoke the Bedrock Converse API
bedrock_runtime = boto3.client(
    service_name="bedrock-runtime",
    region_name="us-east-1"
)

bedrock_agent_runtime = boto3.client(
    service_name="bedrock-agent-runtime",
    region_name="us-east-1"
)

# Check which models are available in your account
models = bedrock.list_inference_profiles()
for model in models["inferenceProfileSummaries"]:
  print(model["inferenceProfileName"] + " - " + model["inferenceProfileId"])
# Out:
# US Anthropic Claude 3 Sonnet - us.anthropic.claude-3-sonnet-20240229-v1:0
# US Anthropic Claude 3 Opus - us.anthropic.claude-3-opus-20240229-v1:0
# US Anthropic Claude 3 Haiku - us.anthropic.claude-3-haiku-20240307-v1:0
# US Meta Llama 3.2 11B Instruct - us.meta.llama3-2-11b-instruct-v1:0
# US Meta Llama 3.2 3B Instruct - us.meta.llama3-2-3b-instruct-v1:0
# US Meta Llama 3.2 90B Instruct - us.meta.llama3-2-90b-instruct-v1:0
# US Meta Llama 3.2 1B Instruct - us.meta.llama3-2-1b-instruct-v1:0
# US Anthropic Claude 3.5 Sonnet - us.anthropic.claude-3-5-sonnet-20240620-v1:0
# US Anthropic Claude 3.5 Haiku - us.anthropic.claude-3-5-haiku-20241022-v1:0
# US Meta Llama 3.1 8B Instruct - us.meta.llama3-1-8b-instruct-v1:0
# US Meta Llama 3.1 70B Instruct - us.meta.llama3-1-70b-instruct-v1:0
# US Nova Lite - us.amazon.nova-lite-v1:0
# US Nova Pro - us.amazon.nova-pro-v1:0
# US Nova Micro - us.amazon.nova-micro-v1:0
# US Meta Llama 3.3 70B Instruct - us.meta.llama3-3-70b-instruct-v1:0
# US Anthropic Claude 3.5 Sonnet v2 - us.anthropic.claude-3-5-sonnet-20241022-v2:0

# %% [markdown]
# # Generate synthetic data
#
# In this notebook, we consider a use case of leveraging a LLM to generate product descriptions that can be used in advising the product on a e-commerce page. The first step is to generate a list of products and for each of them, instruct Amazon Nova Lite to
# generate brief product descriptions.

# %%
# Let's prompt the model to generate 50 products

messages = [
    {"role": "user", "content": [{"text": "For a variety of 50 different product categories sold on a e-commerce website, \
    generate one product that is interesting to a consumer. The product names should be reflective of the actual product being sold. \
    Generate the 50 product items as comma separated values. Do not generate any additional words apart from the product names"}
                                ]
    },
]

# Make the API call to the Nova Lite model
model_response = bedrock_runtime.converse(
    modelId='us.amazon.nova-lite-v1:0', 
    messages=messages
)

# Print the generated text
print("\n[Response Content Text]")
print(model_response['output']['message']['content'][0]['text'])
# Out:
# [Response Content Text]
# "SmartHome Voice Assistant", "Eco-Friendly Reusable Water Bottle", "Wireless Noise-Canceling Headphones", "Portable Solar Charger", "AI-Powered Personal Fitness Coach", "Ergonomic Standing Desk Converter", "Augmented Reality Glasses", "High-Resolution 4K Smart TV", "Multi-Functional Electric Pressure Cooker", "Smart Home Security Camera", "Foldable Electric Scooter", "Smart Sleep Mask", "Biodegradable Dishwashing Tablets", "Compact Travel Vacuum Cleaner", "Smart Pet Feeder", "Handheld Cordless Vacuum", "Smart Indoor Herb Garden", "UV-C Disinfection Box", "Wearable Fitness Tracker", "Smart Refrigerator", "Noise-Canceling Earplugs", "Automated Pet Walking Robot", "High-Capacity Portable Charger", "Smart Air Purifier", "Electric Toothbrush with Smart Sensor", "Smart Lock with Fingerprint Access", "GPS-Enabled Smart Dog Collar", "Smart LED Desk Lamp", "Portable Mini Projector", "Smart Irrigation System", "Voice-Activated Home Assistant", "Robot Vacuum Cleaner", "Smart Sleep Apnea Monitor", "Electric Toothbrush with UV Sterilizer", "Smart Doorbell Camera", "Electric Hydrotherapy Shower Head", "Smart Cooking Pot", "Electric Mosquito Repellent Racket", "Smart Plant Watering System", "Smart Bed Frame with Sleep Tracker", "Smart Home Energy Monitor", "Smart Coffee Maker with App Control", "Electric Heated Blanket", "Smart Wine Cooler", "Smart Lock with Keypad Access", "Electric Car Jump Starter", "Smart Pet Fountain", "Smart Luggage with GPS Tracker", "Electric Standing Desk"

# %%
products_text = model_response['output']['message']['content'][0]['text']
products = [item.strip() for item in products_text.split(",")]

for prd in products:
    print(prd)
# Out:
# "SmartHome Voice Assistant"
# "Eco-Friendly Reusable Water Bottle"
# "Wireless Noise-Canceling Headphones"
# "Portable Solar Charger"
# "AI-Powered Personal Fitness Coach"
# "Ergonomic Standing Desk Converter"
# "Augmented Reality Glasses"
# "High-Resolution 4K Smart TV"
# "Multi-Functional Electric Pressure Cooker"
# "Smart Home Security Camera"
# "Foldable Electric Scooter"
# "Smart Sleep Mask"
# "Biodegradable Dishwashing Tablets"
# "Compact Travel Vacuum Cleaner"
# "Smart Pet Feeder"
# "Handheld Cordless Vacuum"
# "Smart Indoor Herb Garden"
# "UV-C Disinfection Box"
# "Wearable Fitness Tracker"
# "Smart Refrigerator"
# "Noise-Canceling Earplugs"
# "Automated Pet Walking Robot"
# "High-Capacity Portable Charger"
# "Smart Air Purifier"
# "Electric Toothbrush with Smart Sensor"
# "Smart Lock with Fingerprint Access"
# "GPS-Enabled Smart Dog Collar"
# "Smart LED Desk Lamp"
# "Portable Mini Projector"
# "Smart Irrigation System"
# "Voice-Activated Home Assistant"
# "Robot Vacuum Cleaner"
# "Smart Sleep Apnea Monitor"
# "Electric Toothbrush with UV Sterilizer"
# "Smart Doorbell Camera"
# "Electric Hydrotherapy Shower Head"
# "Smart Cooking Pot"
# "Electric Mosquito Repellent Racket"
# "Smart Plant Watering System"
# "Smart Bed Frame with Sleep Tracker"
# "Smart Home Energy Monitor"
# "Smart Coffee Maker with App Control"
# "Electric Heated Blanket"
# "Smart Wine Cooler"
# "Smart Lock with Keypad Access"
# "Electric Car Jump Starter"
# "Smart Pet Fountain"
# "Smart Luggage with GPS Tracker"
# "Electric Standing Desk"

# %% [markdown]
# #### For each of the products, we will now generate product descriptions using Amazon Nova Lite, and capture the traces to Langfuse using the ```@observe()``` decorator

# %%
# Generate product descriptions for each product

@observe()
def general_chat(
    product,
    messages: List[Dict[str, Any]],
    prompt: Optional[PromptClient] = None,
    **kwargs,
) -> str | None:
    # 1. extract model metadata
    #modelId = "anthropic.claude-3-haiku-20240307-v1:0"
    modelId = "us.amazon.nova-lite-v1:0"
    inferenceConfig = {"maxTokens": 500, "temperature": 0.1}
    #additionalModelRequestFields = {"top_k": 250}, this seems to be causing the issue with Nova model, need to revist
    additionalModelRequestFields = {}

    model_parameters = {**inferenceConfig, **additionalModelRequestFields}

    langfuse_context.update_current_observation(
        input=messages,
        model=modelId,
        model_parameters=model_parameters,
        prompt=prompt,
        metadata=kwargs,
    )
    
    langfuse_context.update_current_trace(
        name=f"Description of '{product}'",
        tags=["bedrock_eval_pipelines"]
    )

    # Extract the system prompts from the messages and convert them to the format expected by the Bedrock Converse API
    system_prompts = [
        {"text": message["content"]}
        for message in messages
        if message["role"] == "system"
    ]

    # Convert the rest of messages to the format expected by the Bedrock Converse API
    messages = [
        {
            "role": message["role"],
            "content": (
                message["content"]
                if isinstance(message["content"], list)
                else [{"text": message["content"]}]
            ),
        }
        for message in messages
        if message["role"] != "system"  # Add this condition
    ]

    # 2. model call with error handling
    try:
        response = bedrock_runtime.converse(
            modelId=modelId,
            messages=messages,
            system=system_prompts,
            inferenceConfig=inferenceConfig,
            additionalModelRequestFields=additionalModelRequestFields,
            **kwargs,
        )
    except (ClientError, Exception) as e:
        error_message = f"ERROR: Can't invoke '{modelId}'. Reason: {e}"
        langfuse_context.update_current_observation(
            level="ERROR", status_message=error_message
        )
        print(error_message)
        return

    # 3. extract response metadata
    response_text = response["output"]["message"]["content"][0]["text"]
    langfuse_context.update_current_observation(
        output=response_text,
        usage={
            "input": response["usage"]["inputTokens"],
            "output": response["usage"]["outputTokens"],
            "total": response["usage"]["totalTokens"],
        },
        metadata={
            "ResponseMetadata": response["ResponseMetadata"],
        },
    )

    return response_text
 
prompt_template = "You are a product marketer and you need to generate detailed \
product descriptions for products which will be used for selling \
the product on a e-commerce website. Any catchy phrases from the \
descriptions will also be used for social meda campaigns. \
From the product descriptions, customers should be able to understand \
how the product can help them in their lives but also be able to trust \
this company. Your descriptions are fun and engaging. \
Your answer should be 4 sentences at max."

for product in products:
    print(f"Input: Generate a description for {product}")
    messages = [
        {"role": "system", "content": prompt_template},
        {"role": "user", "content": f"Generate a description for {product}"}
    ]
    print(f"Answer: {general_chat(product, messages)} \n")
# Out:
# Input: Generate a description for "SmartHome Voice Assistant"
# Answer: Unleash the power of voice control with our SmartHome Voice Assistant! Seamlessly integrate and command your smart devices effortlessly. Experience convenience and efficiency like never before, transforming your home into a futuristic haven. Trust in our cutting-edge technology to simplify your life effortlessly.
#
# Input: Generate a description for "Eco-Friendly Reusable Water Bottle"
# Answer: Quench your thirst sustainably with our Eco-Friendly Reusable Water Bottle! Crafted from BPA-free materials, it's your perfect companion for a greener lifestyle. Stay hydrated on-the-go while reducing plastic waste—because every sip counts! Join the movement and sip smart today.
#
# Input: Generate a description for "Wireless Noise-Canceling Headphones"
# Answer: Elevate your audio experience with our Wireless Noise-Canceling Headphones! Immerse yourself in crystal-clear sound, while the advanced noise-cancellation technology blocks out distractions. Perfect for work, travel, or relaxation, these headphones are your ultimate companion for an uninterrupted, enjoyable journey. Trust in our quality and redefine your listening experience today!
#
# Input: Generate a description for "Portable Solar Charger"
# Answer: Light up your life on-the-go with our Portable Solar Charger! Harness the power of the sun to keep your devices fully charged, anytime, anywhere. Say goodbye to dead batteries and hello to endless adventures. Trust in our reliable, eco-friendly tech to power your world.
#
# Input: Generate a description for "AI-Powered Personal Fitness Coach"
# Answer: Unleash your potential with our AI-Powered Personal Fitness Coach! Tailored workouts, real-time feedback, and progress tracking—all designed to help you crush your fitness goals. Experience the future of personal training, right at your fingertips. Join the fitness revolution today!
#
# Input: Generate a description for "Ergonomic Standing Desk Converter"
# Answer: Transform your workspace with our Ergonomic Standing Desk Converter, turning any desk into a height-adjustable haven. Boost your productivity and health by effortlessly switching between sitting and standing throughout the day. Experience the perfect blend of comfort and style, making every work moment better. Trust in our commitment to quality and innovation for a smarter, healthier you.
#
# Input: Generate a description for "Augmented Reality Glasses"
# Answer: Discover the future with our Augmented Reality Glasses! Seamlessly blend digital information with your reality, enhancing your everyday experiences. Whether navigating a new city or troubleshooting a DIY project, these glasses are your ultimate companion. Elevate your life with cutting-edge tech today!
#
# Input: Generate a description for "High-Resolution 4K Smart TV"
# Answer: Experience crystal-clear visuals with our High-Resolution 4K Smart TV, transforming your living room into a cinematic haven. Seamlessly connect to your favorite apps and stream your preferred content effortlessly. Revel in vibrant colors and sharp details, making every moment more immersive. Trust in our cutting-edge technology to elevate your entertainment experience.
#
# Input: Generate a description for "Multi-Functional Electric Pressure Cooker"
# Answer: Elevate your cooking game with our Multi-Functional Electric Pressure Cooker – where convenience meets culinary excellence! Effortlessly whip up delicious meals in a fraction of the time, freeing up your day for what truly matters. Trust in our precision engineering to deliver consistent, restaurant-quality results every time. Experience the perfect blend of innovation and reliability with every pressure-cooked delight!
#
# Input: Generate a description for "Smart Home Security Camera"
# Answer: Capture every moment with our Smart Home Security Camera, your vigilant guardian in every room. Effortlessly monitor your home with crystal-clear HD video, day or night. Experience peace of mind knowing your space is protected, all from the palm of your hand. Join the smart home revolution and secure your sanctuary today.
#
# Input: Generate a description for "Foldable Electric Scooter"
# Answer: Unleash the freedom of effortless rides with our sleek, foldable electric scooter! Glide through city streets or park trails with ease, thanks to its powerful motor and smooth handling. Compact and portable, it's your perfect companion for quick commutes and adventurous escapades. Ride with confidence, knowing you're on a product built for reliability and joy.
#
# Input: Generate a description for "Smart Sleep Mask"
# Answer: Elevate your slumber with our Smart Sleep Mask, designed to block out light and noise for the ultimate restful night. Experience the future of sleep technology, tailored to enhance your relaxation and rejuvenate your mornings. Trust in our commitment to quality and innovation, ensuring you wake up refreshed and ready to seize the day. Join the smart sleep revolution today!
#
# Input: Generate a description for "Biodegradable Dishwashing Tablets"
# Answer: Say goodbye to dishwashing woes with our Biodegradable Dishwashing Tablets! Effortlessly clean your dishes while protecting our planet. These eco-friendly tablets are gentle on your hands and kind to the environment. Upgrade your dishwashing routine today!
#
# Input: Generate a description for "Compact Travel Vacuum Cleaner"
# Answer: Discover the ultimate travel companion with our Compact Travel Vacuum Cleaner! Effortlessly clean up messes on the go, whether you're jet-setting across the globe or just tidying your car. Lightweight and portable, it's your secret weapon against dust and dirt. Trust in our quality to keep your adventures spotless!
#
# Input: Generate a description for "Smart Pet Feeder"
# Answer: Say goodbye to mealtime stress with our Smart Pet Feeder! Automate feeding schedules, monitor food levels, and even dispense treats via a simple app. Your pets will thank you, and you'll love the convenience. Feed smarter, not harder!
#
# Input: Generate a description for "Handheld Cordless Vacuum"
# Answer: Discover the ultimate cleaning companion with our Handheld Cordless Vacuum! Effortlessly glide through your home, banishing dust and debris with ease. Lightweight and powerful, it’s your ticket to a spotless living space anytime, anywhere. Say goodbye to cumbersome cords and hello to hassle-free cleaning!
#
# Input: Generate a description for "Smart Indoor Herb Garden"
# Answer: Elevate your culinary adventures with our Smart Indoor Herb Garden! Effortlessly grow fresh herbs year-round with intuitive technology. Savor the convenience of gourmet flavors at your fingertips. Join our community of herb enthusiasts today!
#
# Input: Generate a description for "UV-C Disinfection Box"
# Answer: Eliminate germs with ease using our UV-C Disinfection Box! Simply place your essentials inside, activate the powerful UV-C light, and let it sanitize your items in minutes. Trust in our cutting-edge technology to keep you and your loved ones safe. Experience peace of mind with every use!
#
# Input: Generate a description for "Wearable Fitness Tracker"
# Answer: Elevate your fitness journey with our Wearable Fitness Tracker! Seamlessly blending style and tech, it monitors your steps, heart rate, and sleep patterns, empowering you to live healthier. Trust in our cutting-edge technology to guide you every step of the way. Get ready to transform your life, one beat at a time!
#
# Input: Generate a description for "Smart Refrigerator"
# Answer: Introducing our Smart Refrigerator, the ultimate kitchen companion that keeps your food fresh and your life connected! With intuitive touch controls and real-time inventory tracking, it's like having a personal chef and grocery shopper. Stay organized, reduce waste, and enjoy smarter meal planning. Upgrade your kitchen with the future of food management today!
#
# Input: Generate a description for "Noise-Canceling Earplugs"
# Answer: Elevate your peace with our Noise-Cancelling Earplugs, designed to block out distractions while you work, sleep, or relax. Experience serene silence in noisy environments, crafted for comfort and durability. Trust in our quality to enhance your daily life, one peaceful moment at a time.
#
# Input: Generate a description for "Automated Pet Walking Robot"
# Answer: Say goodbye to pet walking worries with our Automated Pet Walking Robot! Effortlessly stroll your furry friend with precision and care, ensuring they stay active and happy. Trust in our cutting-edge technology to provide the best for your pet. Join the revolution of pet care today!
#
# Input: Generate a description for "High-Capacity Portable Charger"
# Answer: Light up your adventures with our High-Capacity Portable Charger, your ultimate power buddy on-the-go! Say goodbye to dead batteries and hello to endless possibilities. Compact yet powerful, it ensures your devices stay charged, so you never miss a moment. Trust in our quality – because life shouldn’t pause for a battery check.
#
# Input: Generate a description for "Smart Air Purifier"
# Answer: Breathe easy with our Smart Air Purifier, your ultimate ally against pollutants! Effortlessly purifying the air, it’s perfect for homes, offices, and anywhere you need crisp, clean air. Experience the joy of fresh air with intuitive smart controls and whisper-quiet operation. Trust in our commitment to your health and comfort!
#
# Input: Generate a description for "Electric Toothbrush with Smart Sensor"
# Answer: Elevate your oral hygiene with our Electric Toothbrush with Smart Sensor – your perfect partner in achieving a dazzling smile! This innovative brush adapts to your brushing style, ensuring optimal cleaning while being gentle on your teeth. Experience the joy of a thorough clean with real-time feedback, making every brush a confident one. Trust in quality and innovation for a brighter, healthier you!
#
# Input: Generate a description for "Smart Lock with Fingerprint Access"
# Answer: Unlock a world of convenience with our Smart Lock with Fingerprint Access – your ultimate guardian of home security. Simply scan your fingerprint, and let the magic happen! Say goodbye to lost keys and hello to effortless entry. Trust in our cutting-edge technology to keep your sanctuary safe and sound.
#
# Input: Generate a description for "GPS-Enabled Smart Dog Collar"
# Answer: Unleash the explorer in your furry friend with our GPS-Enabled Smart Dog Collar! Effortlessly track your dog's whereabouts in real-time, ensuring peace of mind during adventures. Stylish, durable, and packed with smart features, it's the perfect companion for every paw-some journey. Trust in our commitment to your pet's safety and style!
#
# Input: Generate a description for "Smart LED Desk Lamp"
# Answer: Illuminate your workspace with our Smart LED Desk Lamp, blending sleek design with cutting-edge technology. Experience adjustable brightness and color temperature to suit any mood or task. Elevate your productivity and eye comfort effortlessly. Trust in quality that brightens your life, one desk at a time.
#
# Input: Generate a description for "Portable Mini Projector"
# Answer: Illuminate your adventures with our Portable Mini Projector! Compact yet powerful, it transforms any space into your personal cinema. Perfect for movie nights, presentations, or gaming on the go. Trust in our quality to brighten your moments, wherever you are.
#
# Input: Generate a description for "Smart Irrigation System"
# Answer: Transform your garden into a lush oasis with our Smart Irrigation System! Say goodbye to guesswork and hello to precise watering, saving both time and water. Experience smarter gardening with real-time weather adjustments and customizable schedules. Trust in our innovation for a greener, more efficient tomorrow.
#
# Input: Generate a description for "Voice-Activated Home Assistant"
# Answer: Transform your home with our Voice-Activated Home Assistant, your ultimate smart companion! Seamlessly control lights, thermostat, and more with just your voice. Experience convenience and efficiency like never before, making daily tasks effortless. Trust in our cutting-edge technology to elevate your living experience.
#
# Input: Generate a description for "Robot Vacuum Cleaner"
# Answer: Say goodbye to dust bunnies! Our Robot Vacuum Cleaner effortlessly glides across floors, capturing every speck of dust and debris. Experience the joy of a spotless home with minimal effort. Trust in our cutting-edge technology for a cleaner, healthier living space.
#
# Input: Generate a description for "Smart Sleep Apnea Monitor"
# Answer: Say goodbye to restless nights with our Smart Sleep Apnea Monitor! Experience uninterrupted sleep and wake up refreshed, knowing you're in safe hands. Our cutting-edge technology ensures you get the rest you deserve, while providing peace of mind. Join the sleep revolution today!
#
# Input: Generate a description for "Electric Toothbrush with UV Sterilizer"
# Answer: Elevate your oral hygiene with our Electric Toothbrush featuring a UV Sterilizer! Say goodbye to germs and hello to a sparkling smile. Experience the perfect blend of advanced technology and gentle care for healthier teeth and gums. Trust in quality, trust in brilliance!
#
# Input: Generate a description for "Smart Doorbell Camera"
# Answer: Elevate your home security with our Smart Doorbell Camera – the ultimate blend of style and safety. Capture every visitor in vibrant HD and receive instant alerts on your smartphone. Enjoy peace of mind with night vision and two-way audio, ensuring you're always connected. Transform your front door into a smart hub with seamless integration and easy installation.
#
# Input: Generate a description for "Electric Hydrotherapy Shower Head"
# Answer: Dive into luxury with our Electric Hydrotherapy Shower Head, transforming your daily routine into a spa-like experience. Feel the invigorating massage of targeted jets, melting away stress and revitalizing your senses. Trust in our cutting-edge technology for a refreshing boost every morning. Elevate your shower, elevate your life.
#
# Input: Generate a description for "Smart Cooking Pot"
# Answer: Elevate your culinary game with our Smart Cooking Pot! Effortlessly prepare gourmet meals with precise temperature control and automated cooking modes. Experience the joy of hassle-free cooking while saving time and energy. Trust in our innovation to bring deliciousness to your table every day.
#
# Input: Generate a description for "Electric Mosquito Repellent Racket"
# Answer: Zap away those pesky mosquitoes with our Electric Mosquito Repellent Racket! Enjoy uninterrupted outdoor fun with its powerful, non-toxic zap technology. Lightweight and easy to use, it's your perfect summer companion. Trust in our quality – say goodbye to bites, hello to bliss!
#
# Input: Generate a description for "Smart Plant Watering System"
# Answer: Say goodbye to wilted plants and hello to vibrant greenery with our Smart Plant Watering System! Effortlessly keep your indoor and outdoor plants thriving with precise, automated watering tailored to each plant's needs. Enjoy peace of mind and lush, healthy plants without the hassle. Transform your green thumb into a smart gardener today!
#
# Input: Generate a description for "Smart Bed Frame with Sleep Tracker"
# Answer: Elevate your sleep game with our Smart Bed Frame, seamlessly integrating a sleep tracker to monitor and enhance your rest. Experience the future of sleep technology, providing insights to help you wake up refreshed and ready for the day. Trust in our commitment to quality and innovation, ensuring you achieve the best night's sleep ever. Join the sleep revolution today!
#
# Input: Generate a description for "Smart Home Energy Monitor"
# Answer: Transform your home into an energy-savvy haven with our Smart Home Energy Monitor! Instantly track and manage your energy consumption, reduce your carbon footprint, and save on bills effortlessly. Experience peace of mind knowing you're in control, while our sleek design seamlessly integrates into your lifestyle.
#
# Input: Generate a description for "Smart Coffee Maker with App Control"
# Answer: Brew your perfect cup effortlessly with our Smart Coffee Maker! Seamlessly blend technology and tradition, controlling your brew from your phone. Experience personalized coffee at home, tailored to your taste. Trust in quality, trust in innovation – your perfect brew, just a tap away.
#
# Input: Generate a description for "Electric Heated Blanket"
# Answer: Experience cozy warmth with our Electric Heated Blanket, perfect for chilly nights and lazy weekends. Simply adjust the temperature to your liking and relax in snug bliss. Crafted with quality materials, it ensures safety and durability. Trust us to bring comfort and reliability into your home.
#
# Input: Generate a description for "Smart Wine Cooler"
# Answer: Elevate your wine experience with our Smart Wine Cooler, the ultimate companion for wine connoisseurs. Effortlessly maintain your favorite vintages at the perfect temperature with intuitive touch controls. Enjoy the luxury of perfectly chilled wines with our sleek, space-saving design. Trust in our precision technology for an unforgettable tasting journey.
#
# Input: Generate a description for "Smart Lock with Keypad Access"
# Answer: Unlock convenience with our Smart Lock with Keypad Access, seamlessly blending security with simplicity. Effortlessly secure your home with a unique PIN, and bid farewell to lost keys. Experience peace of mind with real-time alerts and remote control via your smartphone. Trust in cutting-edge technology for a smarter, safer lifestyle.
#
# Input: Generate a description for "Electric Car Jump Starter"
# Answer: Power up your adventures with our Electric Car Jump Starter – your trusty sidekick for those unexpected roadside emergencies! Compact, lightweight, and packed with 10,000mAh of pure power, it's your ticket back on the road in minutes. Say goodbye to dead batteries and hello to peace of mind, wherever your journey takes you. Trust in reliability, drive with confidence!
#
# Input: Generate a description for "Smart Pet Fountain"
# Answer: Quench your pet's thirst with our Smart Pet Fountain, combining convenience and cutting-edge tech! Enjoy peace of mind knowing your furry friend always has fresh, clean water. Sleek design and automatic refills make pet care effortless. Elevate your pet's hydration game today!
#
# Input: Generate a description for "Smart Luggage with GPS Tracker"
# Answer: Travel with ease and confidence using our Smart Luggage with GPS Tracker! Say goodbye to lost luggage worries, as our innovative GPS feature allows you to locate your bag anywhere, anytime. Lightweight and durable, it's perfect for both business trips and adventurous vacations. Experience the future of travel with our Smart Luggage today!
#
# Input: Generate a description for "Electric Standing Desk"
# Answer: Elevate your workspace with our Electric Standing Desk, transforming your daily routine into a healthier, more productive experience. Seamlessly transition between sitting and standing with just the touch of a button, reducing fatigue and boosting energy levels. Experience the perfect blend of modern design and ergonomic functionality, making it an essential addition to any home or office. Invest in your well-being and productivity today!

# %% [markdown]
# ### Now you should see these product descriptions in the Traces section of the langfuse UI.
# ![Traces collected from the LLM generations](product_description_traces.png "Langfuse Traces")

# %% [markdown]
# The goal of this tutorial is to show you how to build an external evaluation pipeline. These pipelines will run in your CI/CD environment, or be run in a different orchestrated container service. No matter the environment you choose, three key steps always apply:
#
# 1. Fetch Your Traces: Get your application traces to your evaluation environment
# 2. Run Your Evaluations: Apply any evaluation logic you prefer
# 3. Save Your Results: Attach your evaluations back to the Langfuse trace used for calculating them.
#
# ***
# Goal: This evaluation pipeline is executed on all the traces over the past 24 hours
# ***

# %% [markdown]
# ## 1. Fetch the traces
#
# The ```fetch_traces()``` function has arguments to filter the traces by tags, timestamps, and beyond. We can also choose the number of samples for pagination.

# %%
from langfuse import Langfuse
from datetime import datetime, timedelta
 
BATCH_SIZE = 10
TOTAL_TRACES = 50
 
now = datetime.now()
last_24_hours = now - timedelta(days=1)

langfuse = Langfuse(
    secret_key=os.environ["LANGFUSE_SECRET_KEY"],
    public_key=os.environ["LANGFUSE_PUBLIC_KEY"],
    host="https://us.cloud.langfuse.com" 
)
 
traces_batch = langfuse.fetch_traces(page=1,
                                     limit=BATCH_SIZE,
                                     tags="bedrock_eval_pipelines",
                                     from_timestamp=last_24_hours,
                                     to_timestamp=datetime.now()
                                   ).data
 
print(f"Traces in first batch: {len(traces_batch)}")
# Out:
# Traces in first batch: 10

# %%
traces_batch[1]
# Out:
# TraceWithDetails(id='3e4f798e-4a3d-4118-9a2d-470da4829402', timestamp=datetime.datetime(2025, 2, 15, 18, 49, 57, 617000, tzinfo=datetime.timezone.utc), name='Description of \'"Smart Luggage with GPS Tracker"\'', input=[{'role': 'system', 'content': 'You are a product marketer and you need to generate detailed product descriptions for products which will be used for selling the product on a e-commerce website. Any catchy phrases from the descriptions will also be used for social meda campaigns. From the product descriptions, customers should be able to understand how the product can help them in their lives but also be able to trust this company. Your descriptions are fun and engaging. Your answer should be 4 sentences at max.'}, {'role': 'user', 'content': 'Generate a description for "Smart Luggage with GPS Tracker"'}], output="Travel with ease and confidence using our Smart Luggage with GPS Tracker! Say goodbye to lost luggage worries, as our innovative GPS feature allows you to locate your bag anywhere, anytime. Lightweight and durable, it's perfect for both business trips and adventurous vacations. Experience the future of travel with our Smart Luggage today!", session_id=None, release=None, version=None, user_id=None, metadata={'ResponseMetadata': {'RequestId': 'b91d666e-9cfe-430e-b3eb-715a90525951', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sat, 15 Feb 2025 18:49:58 GMT', 'content-type': 'application/json', 'content-length': '523', 'connection': 'keep-alive', 'x-amzn-requestid': 'b91d666e-9cfe-430e-b3eb-715a90525951'}, 'RetryAttempts': 0}}, tags=['bedrock_eval_pipelines'], public=False, html_path='/project/cm72kyx5d00d9ad08na7yvcoy/traces/3e4f798e-4a3d-4118-9a2d-470da4829402', latency=0.0, total_cost=0.0, observations=[], scores=[], bookmarked=False, createdAt='2025-02-15T18:49:59.000Z', updatedAt='2025-02-15T18:50:03.285Z', externalId=None, projectId='cm72kyx5d00d9ad08na7yvcoy')

# %% [markdown]
# ## 2. Categorical Evaluation using LLM-as-a-judge
#
# Evaluation functions should take a trace as input and yield a valid score.
# When analyzing the outputs of your LLM applications, you may want to evaluate traits that are defined qualitatively such as readability, helpfulness or measures for reducing hallucinations such as completeness.
#
# We're building product descriptions and to ensure it resonates with customers, we want to measure readability. For more LLM-as-a-judge definitions, check out the judge based evaluator prompts defined in the [Amazon Bedrock Evaluator Prompts](https://docs.aws.amazon.com/bedrock/latest/userguide/model-evaluation-type-judge-prompt.html)

# %%
template_readability = """
You are a helpful agent that can assess an LLM response according to the given rubrics.

You are given a product description generated by a LLM. Your task is to assess the readability of the LLM response to the question, in other words, how easy it is for a typical reading audience to comprehend the response at a normal reading rate.

Please rate the readability of the response based on the following scale:
- unreadable: The response contains gibberish or could not be comprehended by any normal audience.
- poor readability: The response is comprehensible, but it is full of poor readability factors that make comprehension very challenging.
- fair readability: The response is comprehensible, but there is a mix of poor readability and good readability factors, so the average reader would need to spend some time processing the text in order to understand it.
- good readability: Very few poor readability factors. Mostly clear, well-structured sentences. Standard vocabulary with clear context for any challenging words. Clear organization with topic sentences and supporting details. The average reader could comprehend by reading through quickly one time.
- excellent readability: No poor readability factors. Consistently clear, concise, and varied sentence structures. Simple, widely understood vocabulary. Logical organization with smooth transitions between ideas. The average reader may be able to skim the text and understand all necessary points.

Here is the product description that needs to be evaluated: {prd_desc}

Firstly explain your response, followed by your final answer. You should follow the format
Explanation: [Explanation], Answer: [Answer],
where '[Answer]' can be one of the following:
```
unreadable
poor readability
fair readability
good readability
excellent readability
```
"""

def generate_readability_score(trace_output):
    prd_desc_readability = template_readability.format(prd_desc=trace_output)
    message_1 = {
        "role": "user",
        "content": [{"text": prd_desc_readability}]
    }
    
    query = [f"Rate the readability of product description: {traces_batch[1].output}"]
    
    readability_score = bedrock_runtime.converse(
        modelId='us.amazon.nova-lite-v1:0', 
        messages = [message_1]
    )
    explanation, score = readability_score['output']['message']['content'][0]['text'].split('\n\n')
    return explanation, score


print(f"User query: {traces_batch[1].input[1]['content']}")
print(f"Model answer: {traces_batch[1].output}")
explanation, score = generate_readability_score(traces_batch[1].output)
print(f"Readability: {score}, Explanation: {explanation}")

# %% [markdown]
# ## 3. Add the evaluation to the trace
#
# Now that we have generated a readability score as well as a explanation, we can use the Langfuse client to add scores to existing traces.

# %%
langfuse.score(
    trace_id=traces_batch[1].id,
    name="readability",
    value=explanation,
    comment=score
)

# %% [markdown]
# # Putting everything together
#
# We just saw how to do this for one trace, let's put it all together in a function to run it on all the traces collected in the last 24 hours.

# %%
import math
 
for page_number in range(1, math.ceil(TOTAL_TRACES/BATCH_SIZE)):
 
    traces_batch = langfuse.fetch_traces(page=1,
                                         limit=BATCH_SIZE,
                                         tags="bedrock_eval_pipelines",
                                         from_timestamp=last_24_hours,
                                         to_timestamp=datetime.now()
                                       ).data
 
    for trace in traces_batch:
        print(f"Processing {trace.name}")
 
        if trace.output is None:
            print(f"Warning: \n Trace {trace.name} had no generated output, \
            it was skipped")
            continue
        explanation, score = generate_readability_score(trace.output)
        langfuse.score(
            trace_id=trace.id,
            name="readability",
            value=score,
            comment=explanation
        )
 
    print(f"Batch {page_number} processed 🚀 \n")
# Out:
# Processing Description of '"Electric Standing Desk"'
# Processing Description of '"Smart Luggage with GPS Tracker"'
# Processing Description of '"Smart Pet Fountain"'
# Processing Description of '"Electric Car Jump Starter"'
# Processing Description of '"Smart Lock with Keypad Access"'
# Processing Description of '"Smart Wine Cooler"'
# Processing Description of '"Electric Heated Blanket"'
# Processing Description of '"Smart Coffee Maker with App Control"'
# Processing Description of '"Smart Home Energy Monitor"'
# Processing Description of '"Smart Bed Frame with Sleep Tracker"'
# Batch 1 processed 🚀
#
# Processing Description of '"Electric Standing Desk"'
# Processing Description of '"Smart Luggage with GPS Tracker"'
# Processing Description of '"Smart Pet Fountain"'
# Processing Description of '"Electric Car Jump Starter"'
# Processing Description of '"Smart Lock with Keypad Access"'
# Processing Description of '"Smart Wine Cooler"'
# Processing Description of '"Electric Heated Blanket"'
# Processing Description of '"Smart Coffee Maker with App Control"'
# Processing Description of '"Smart Home Energy Monitor"'
# Processing Description of '"Smart Bed Frame with Sleep Tracker"'
# Batch 2 processed 🚀
#
# Processing Description of '"Electric Standing Desk"'
# Processing Description of '"Smart Luggage with GPS Tracker"'
# Processing Description of '"Smart Pet Fountain"'
# Processing Description of '"Electric Car Jump Starter"'
# Processing Description of '"Smart Lock with Keypad Access"'
# Processing Description of '"Smart Wine Cooler"'
# Processing Description of '"Electric Heated Blanket"'
# Processing Description of '"Smart Coffee Maker with App Control"'
# Processing Description of '"Smart Home Energy Monitor"'
# Processing Description of '"Smart Bed Frame with Sleep Tracker"'
# Batch 3 processed 🚀
#
# Processing Description of '"Electric Standing Desk"'
# Processing Description of '"Smart Luggage with GPS Tracker"'
# Processing Description of '"Smart Pet Fountain"'
# Processing Description of '"Electric Car Jump Starter"'
# Processing Description of '"Smart Lock with Keypad Access"'
# Processing Description of '"Smart Wine Cooler"'
# Processing Description of '"Electric Heated Blanket"'
# Processing Description of '"Smart Coffee Maker with App Control"'
# Processing Description of '"Smart Home Energy Monitor"'
# Processing Description of '"Smart Bed Frame with Sleep Tracker"'
# Batch 4 processed 🚀

# %% [markdown]
# #### If your pipeline ran successfully, you should now see scores added to your traces
#
# ![Langfuse Trace with score added for readability](scored_trace.png "Scored trace on langfuse")
